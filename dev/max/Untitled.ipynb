# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
infant_state_df = pd.read_csv("Infant_state.csv")
infant_state_df.head()
# Out:
#    YEAR STATE  RATE DEATHS                                               URL
# 0  2017    AL   7.4    434        /nchs/pressroom/states/alabama/alabama.htm
# 1  2017    AK   5.6     59          /nchs/pressroom/states/alaska/alaska.htm
# 2  2017    AZ   5.7    469        /nchs/pressroom/states/arizona/arizona.htm
# 3  2017    AR   8.2    307      /nchs/pressroom/states/arkansas/arkansas.htm
# 4  2017    CA   4.2  1,973  /nchs/pressroom/states/california/california.htm

# %%
pure_data = infant_state_df.drop(columns=['URL'])

# %%
year_data = pure_data[:50]

# %%
year_data
# Out:
#     YEAR STATE  RATE DEATHS
# 0   2017    AL   7.4    434
# 1   2017    AK   5.6     59
# 2   2017    AZ   5.7    469
# 3   2017    AR   8.2    307
# 4   2017    CA   4.2  1,973
# 5   2017    CO   4.5    291
# 6   2017    CT   4.5    160
# 7   2017    DE   6.6     72
# 8   2017    FL   6.1  1,358
# 9   2017    GA   7.2    932
# 10  2017    HI   5.3     92
# 11  2017    ID   4.6    102
# 12  2017    IL   6.1    912
# 13  2017    IN   7.3    600
# 14  2017    IA   5.3    203
# 15  2017    KS   6.1    221
# 16  2017    KY   6.5    355
# 17  2017    LA   7.1    431
# 18  2017    ME   5.7     70
# 19  2017    MD   6.4    460
# 20  2017    MA   3.7    262
# 21  2017    MI   6.8    755
# 22  2017    MN   4.8    328
# 23  2017    MS   8.6    322
# 24  2017    MO   6.2    456
# 25  2017    MT   5.4     64
# 26  2017    NE   5.6    144
# 27  2017    NV   5.8    208
# 28  2017    NH   4.2     51
# 29  2017    NJ   4.5    453
# 30  2017    NM   5.9    140
# 31  2017    NY   4.6  1,047
# 32  2017    NC   7.1    847
# 33  2017    ND   4.3     46
# 34  2017    OH   7.2    983
# 35  2017    OK   7.7    387
# 36  2017    OR   5.4    236
# 37  2017    PA   6.1    841
# 38  2017    RI   6.2     66
# 39  2017    SC   6.5    371
# 40  2017    SD   7.7     94
# 41  2017    TN   7.4    597
# 42  2017    TX   5.9  2,237
# 43  2017    UT   5.9    285
# 44  2017    VT   4.8     27
# 45  2017    VA   5.9    592
# 46  2017    WA   3.9    341
# 47  2017    WV   7.0    131
# 48  2017    WI   6.4    414
# 49  2017    WY   4.6     32

# %%
data_sorted = year_data.sort_values('RATE', ascending= False)

# %%
x_axis = np.arange(len(data_sorted))
tick_locations = [value+0.4 for value in x_axis]

# %%
fig = plt.figure(figsize=(20,3))

plt.bar(x_axis, data_sorted["RATE"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, data_sorted["STATE"], rotation="horizontal")
# Out:
# ([<matplotlib.axis.XTick at 0x11fb9ef10>,
#   <matplotlib.axis.XTick at 0x11fb9e6d0>,
#   <matplotlib.axis.XTick at 0x11fb9e590>,
#   <matplotlib.axis.XTick at 0x11fc42b50>,
#   <matplotlib.axis.XTick at 0x11fc4f1d0>,
#   <matplotlib.axis.XTick at 0x11fc4f7d0>,
#   <matplotlib.axis.XTick at 0x11fc4fb50>,
#   <matplotlib.axis.XTick at 0x11fc55250>,
#   <matplotlib.axis.XTick at 0x11fc55810>,
#   <matplotlib.axis.XTick at 0x11fc55e50>,
#   <matplotlib.axis.XTick at 0x11fc5b490>,
#   <matplotlib.axis.XTick at 0x11fc5bad0>,
#   <matplotlib.axis.XTick at 0x11fc62190>,
#   <matplotlib.axis.XTick at 0x11fc62790>,
#   <matplotlib.axis.XTick at 0x11fc62dd0>,
#   <matplotlib.axis.XTick at 0x11fc62710>,
#   <matplotlib.axis.XTick at 0x11fc55210>,
#   <matplotlib.axis.XTick at 0x11fc68350>,
#   <matplotlib.axis.XTick at 0x11fc68990>,
#   <matplotlib.axis.XTick at 0x11fc68a90>,
#   <matplotlib.axis.XTick at 0x11fc70650>,
#   <matplotlib.axis.XTick at 0x11fc70c90>,
#   <matplotlib.axis.XTick at 0x11fc76310>,
#   <matplotlib.axis.XTick at 0x11fc76950>,
#   <matplotlib.axis.XTick at 0x11fc76810>,
#   <matplotlib.axis.XTick at 0x11fc70550>,
#   <matplotlib.axis.XTick at 0x11fc55350>,
#   <matplotlib.axis.XTick at 0x11fc7d590>,
#   <matplotlib.axis.XTick at 0x11fc7dbd0>,
#   <matplotlib.axis.XTick at 0x11fc84250>,
#   <matplotlib.axis.XTick at 0x11fc84890>,
#   <matplotlib.axis.XTick at 0x11fc84ed0>,
#   <matplotlib.axis.XTick at 0x11fc8b550>,
#   <matplotlib.axis.XTick at 0x11fc8bb90>,
#   <matplotlib.axis.XTick at 0x11fc8ba90>,
#   <matplotlib.axis.XTick at 0x11fc8b1d0>,
#   <matplotlib.axis.XTick at 0x11fc769d0>,
#   <matplotlib.axis.XTick at 0x11fc94310>,
#   <matplotlib.axis.XTick at 0x11fc948d0>,
#   <matplotlib.axis.XTick at 0x11fc94f10>,
#   <matplotlib.axis.XTick at 0x11fc99590>,
#   <matplotlib.axis.XTick at 0x11fc99bd0>,
#   <matplotlib.axis.XTick at 0x11fca0250>,
#   <matplotlib.axis.XTick at 0x11fca0890>,
#   <matplotlib.axis.XTick at 0x11fc99990>,
#   <matplotlib.axis.XTick at 0x11fc8bb10>,
#   <matplotlib.axis.XTick at 0x11fca0d50>,
#   <matplotlib.axis.XTick at 0x11fca83d0>,
#   <matplotlib.axis.XTick at 0x11fca8a10>,
#   <matplotlib.axis.XTick at 0x11fca8d50>],
#  <a list of 50 Text xticklabel objects>)
